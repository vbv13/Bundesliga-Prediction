# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Bundesliga_Results.csv")
len(data)
data.head(2000)
# Out:
#      Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     D1    7/8/1993   Bayern Munich        Freiburg     3     1   H   NaN
# 1     D1    7/8/1993        Dortmund       Karlsruhe     2     1   H   NaN
# 2     D1    7/8/1993        Duisburg      Leverkusen     2     2   D   NaN
# 3     D1    7/8/1993         FC Koln  Kaiserslautern     0     2   A   NaN
# 4     D1    7/8/1993         Hamburg        Nurnberg     5     2   H   NaN
# 5     D1    7/8/1993         Leipzig         Dresden     3     3   D   NaN
# 6     D1    7/8/1993      M'Gladbach   Ein Frankfurt     0     4   A   NaN
# 7     D1    7/8/1993    Wattenscheid      Schalke 04     3     0   H   NaN
# 8     D1    7/8/1993   Werder Bremen       Stuttgart     5     1   H   NaN
# 9     D1    14/08/93         Dresden        Duisburg     0     1   A   NaN
# 10    D1    14/08/93   Ein Frankfurt   Werder Bremen     2     2   D   NaN
# ...

# %%
data.head
